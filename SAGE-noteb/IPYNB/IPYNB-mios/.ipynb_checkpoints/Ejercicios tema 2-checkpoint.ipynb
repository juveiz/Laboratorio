# %%
var('a b')
p(x)=x^4-6*x^2 + a*x+ b
solve (p(x),x)
# Out:
# [x == -1/2*sqrt(1/3)*sqrt((4*b + 3*(1/2*a^2 + 8*b + 1/6*sqrt(9*a^4 - 256/3*b^3 - 288*a^2 + 288*(a^2 - 24)*b + 1536*b^2) - 8)^(2/3) + 12*(1/2*a^2 + 8*b + 1/6*sqrt(9*a^4 - 256/3*b^3 - 288*a^2 + 288*(a^2 - 24)*b + 1536*b^2) - 8)^(1/3) + 12)/(1/2*a^2 + 8*b + 1/6*sqrt(9*a^4 - 256/3*b^3 - 288*a^2 + 288*(a^2 - 24)*b + 1536*b^2) - 8)^(1/3)) - 1/2*sqrt(6*sqrt(1/3)*a/sqrt((4*b + 3*(1/2*a^2 + 8*b + 1/6*sqrt(9*a^4 - 256/3*b^3 - 288*a^2 + 288*(a^2 - 24)*b + 1536*b^2) - 8)^(2/3) + 12*(1/2*a^2 + 8*b + 1/6*sqrt(9*a^4 - 256/3*b^3 - 288*a^2 + 288*(a^2 - 24)*b + 1536*b^2) - 8)^(1/3) + 12)/(1/2*a^2 + 8*b + 1/6*sqrt(9*a^4 - 256/3*b^3 - 288*a^2 + 288*(a^2 - 24)*b + 1536*b^2) - 8)^(1/3)) - 4/3*(b + 3)/(1/2*a^2 + 8*b + 1/6*sqrt(9*a^4 - 256/3*b^3 - 288*a^2 + 288*(a^2 - 24)*b + 1536*b^2) - 8)^(1/3) - (1/2*a^2 + 8*b + 1/6*sqrt(9*a^4 - 256/3*b^3 - 288*a^2 + 288*(a^2 - 24)*b + 1536*b^2) - 8)^(1/3) + 8), x == -1/2*sqrt(1/3)*sqrt((4*b + 3*(1/2*a^2 + 8*b + 1/6*sqrt(9*a^4 - 256/3*b^3 - 288*a^2 + 288*(a^2 - 24)*b + 1
# ...

# %%
var ('t')
parametric_plot([sin(t),cos(t)],(t,0,2*pi)) and plot(sin(x),pi/4,-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(e^x-x^e,0,5)
# Out:
# Graphics object consisting of 1 graphics primitive
