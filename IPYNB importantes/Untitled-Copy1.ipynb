# %%
plot(x^4-6*x^2-2,xmin=-20,xmax=20,ymin=-20,ymax=20,color='red') + plot(x^4-6*x^2+2,xmin=-20,xmax=20,ymin=-20,ymax=20) +plot(x^4-6*x^2+12,xmin=-20,xmax=20,ymin=-20,ymax=20,color='green')
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
plot(x^4-6*x^2+8*x,xmin=-20,xmax=20,ymin=-20,ymax=20,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
solve(derivative(x^4-6*x^2+8*x)==0,x)
# Out:
# [x == -2, x == 1]

# %%
solve(derivative(derivative(x^4-6*x^2+8*x))==0,x)
# Out:
# [x == -1, x == 1]

# %%
var ('x y z w')
solve([x-2*y+4*z-8*w==26,x-y+z-w==4,x+y+z+w==8,x+2*y+4*z+8*w==-2],x,y,z,w)
# Out:
# [[x == 4, y == 5, z == 2, w == -3]]

# %%
var('m k')
sum(k^4,k,1,m)
# Out:
# 1/5*m^5 + 1/2*m^4 + 1/3*m^3 - 1/30*m

# %%
var ('x y z w a')
print solve([x+y+z+w+a==1,x+2*y+4*z+8*w+16*a==9,x+3*y+9*z+27*w+81*a==36,x+4*y+16*z+64*w+256*a==100,x+5*y+25*z+125*w+625*a==225],x,y,z,w,a)

var('m k')
sum(k^3,k,1,m)
# Out:
# [
# [x == 0, y == 0, z == (1/4), w == (1/2), a == (1/4)]
# ]
# 1/4*m^4 + 1/2*m^3 + 1/4*m^2
