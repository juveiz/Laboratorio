# %%
var('x y z')
# Out:
# (x, y, z)

# %%
f(x)=x+2

# %%
plot(f(x),-10,10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g(x,y)=x^2+y^2

# %%
plot3d(g,(x,-10,10),(y,-10,10))
# Out:
# Graphics3d Object

# %%
implicit_plot(f,(x,-5,5),(y,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
implicit_plot3d(g,(x,-50,50),(y,-50,50),(z,-50,50))
# Out:
# Graphics3d Object

# %%
f(x)=sin(x)
plot(f(x),-10*pi,10*pi)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x,y)=x^2+(y-(x^2)^(1/3))^2

# %%
implicit_plot((x^2+(y-x^(2/3))^2)==1,(x,-20,20),(y,-20,20))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-3829ac4c761b> in <module>()
# ----> 1 implicit_plot((x**Integer(2)+(y-x**(Integer(2)/Integer(3)))**Integer(2))==Integer(1),(x,-Integer(20),Integer(20)),(y,-Integer(20),Integer(20)))
#
# /projects/sage/sage-7.3/local/lib/python2.7/site-packages/sage/misc/decorators.pyc in wrapper(*args, **kwds)
#     552                 options['__original_opts'] = kwds
#     553             options.update(kwds)
# --> 554             return func(*args, **options)
#     555
#     556         #Add the options specified by @options to the signature of the wrapped
#
# /projects/sage/sage-7.3/local/lib/python2.7/site-packages/sage/plot/contour_plot.pyc in implicit_plot(f, xrange, yrange, **options)
#    1174     elif options['fill'] is False:
#    1175         return contour_plot(f, xrange, yrange, linewidths=linewidths,
# ...

# %%
f(x,y)=1
plot3d(f,(x,-5,5),(y,-5,5))
# Out:
# Graphics3d Object

# %%
f(x)=x^2+1

# %%
def orbita(ini,f):
    L=[]
    while not(ini in L):
        L.append(ini)
        ini=f(ini)
    return L

# %%
orbita(2,f)

# %%
plot(cos(x^2),-2,2)+plot(sin(x^3),-2,2,fill=cos(x^2),fillcolor='green')
# Out:
# Graphics object consisting of 3 graphics primitives
