# %% [markdown]
# plot muestra la gráfica de p evaluado, entre los valores definidos en el segundo argumento.

# %%
p(x,a,b) = x^4 - 6 * x^2 + a*x + b

# %%
show(p)
# Out:
# (x, a, b) |--> x^4 + a*x - 6*x^2 + b

# %%
plot(p(x,0,0), (x, -3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(p(x,0,2), (x, -3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(p(x,0,-9), (x, -3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(p(x,0,99), (x, -3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot3d(p(x,0,b), (x,-3,3), (b,-100,100))
# Out:
# Graphics3d Object

# %%
plot(p(x,8,0), (x, -3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
show(p(x,0,b).factor())
# Out:
# x^4 - 6*x^2 + b

# %%
solve(p(x,0,b),x)
# Out:
# [x == -sqrt(sqrt(-b + 9) + 3), x == sqrt(sqrt(-b + 9) + 3), x == -sqrt(-sqrt(-b + 9) + 3), x == sqrt(-sqrt(-b + 9) + 3)]

# %% [markdown]
# Derivamos para ver donde es 0 (máximos y mínimos)

# %%
g(x) = p(x,8,0).diff(x)

# %%
find_root(g, -1, 3)
# Out:
# 0.9999999977654764

# %%
g(1)
# Out:
# 0

# %%
gdev(x) = g.diff(x)

# %%
gdev(1)
# Out:
# 0
