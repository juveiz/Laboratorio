# %% [markdown]
# a)

# %%
l = x**2/(x + 2)
l.limit(x = +oo)
# Out:
# +Infinity

# %% [markdown]
# b)

# %%
l = x**3/(x**3 + 2*x + 1)
l.limit(x = +oo)
# Out:
# 1

# %% [markdown]
# l)

# %%
l = (3**x + (-2)**x)/(3**(x+1) + (-2)**(x+1))
l.limit(x = +oo)
# Out:
# 1/3

# %% [markdown]
# ñ)

# %%
function = i/x^2
limit(sum(function for i in srange(1,x)), x = +oo)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-554e06238f98> in <module>()
#       1 function = i/x**Integer(2)
# ----> 2 limit(sum(function for i in srange(Integer(1),x)), x = +oo)
#
# sage/arith/srange.pyx in sage.arith.srange.srange (/usr/lib/sagemath//src/build/cythonized/sage/arith/srange.c:4034)()
#
# sage/arith/srange.pyx in xsrange (/usr/lib/sagemath//src/build/cythonized/sage/arith/srange.c:3608)()
#
# sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.__float__ (/usr/lib/sagemath//src/build/cythonized/sage/symbolic/expression.cpp:10434)()
#
# TypeError: unable to simplify to float approximation
