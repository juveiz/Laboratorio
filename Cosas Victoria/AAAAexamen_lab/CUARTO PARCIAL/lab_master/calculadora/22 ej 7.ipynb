# %%
L1 = plot(x^2, (x,-4,4))
var('x, y')
L2 = implicit_plot(x^2+(y-6)^2==9,(x,-3,3),(y,0, 15)) + implicit_plot(x^2+(x^2-6)^2==9,(x,-3,3),(y,0, 15))
show(L1 + L2)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
parabola(x) = x**2

# %%
circulo(x, a, R) = x^2+(y-a)^2 == R
