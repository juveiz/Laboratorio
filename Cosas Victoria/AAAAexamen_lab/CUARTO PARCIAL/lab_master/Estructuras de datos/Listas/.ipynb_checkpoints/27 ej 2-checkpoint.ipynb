# %%
primos = prime_range(100, 1001)

# %%
primos[floor(len(primos)/2)]
# Out:
# 509

# %%
primos.index(331)
# Out:
# 41

# %%
primos.index(631)
# Out:
# 89

# %%
L1 = primos[41:90]

# %%
L2 = primos[::4] + primos[3::4]

# %%
L2.sort()

# %%
L3 = primos[::3] + primos[2::3]
L3.sort()
