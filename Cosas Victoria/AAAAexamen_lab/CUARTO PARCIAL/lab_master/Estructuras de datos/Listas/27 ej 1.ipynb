# %%
L = [3,5,6,8,10,12]

# %%
L.index(8)
# Out:
# 3

# %%
L[L.index(8)] = 9

# %%
L
# Out:
# [3, 5, 6, 9, 10, 12]

# %%
i = L.index(5)
j = L.index(9)

# %%
L[i], L[j] = L[j], L[i] ##swap

# %%
L
# Out:
# [3, 9, 6, 5, 10, 12]

# %%
LL = list(L)
LL.reverse()
LL
# Out:
# [12, 10, 5, 6, 9, 3]

# %%
L
# Out:
# [3, 9, 6, 5, 10, 12]

# %%
L1 = L+LL

# %%
L1
# Out:
# [3, 9, 6, 5, 10, 12, 12, 10, 5, 6, 9, 3]
